# %% [markdown]
# Dear students, in this homework, you will analyze the Titanic dataset. Please read the tasks carefully and ask any questions you have on Discord. The homework consists of 10 tasks with a total of 10 points, but bonus points may be awarded for accuracy in task 10. Good luck and have fun!

# %%
import pandas as pd

# %% [markdown]
# ##Task 1. Read the data and display top 5 rows(0.5 pt)

# %%
df=pd.read_csv('train__2_.csv',delimiter=',')
pd.read_csv('train__2_.csv',delimiter=',')[:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ##Task 2. Print dataframe's columns names and dimensionality(0.5 pt)

# %%
list_of_col=df.columns.values.tolist ()
print("Dataframe's columns names:")
print(*list_of_col,sep="\n")

dem=df.shape
print()
print("The dimensionality of this df:")
print(f"{dem[0]} - numbers of rows")
print(f"{dem[1]} - numbers of columns")
# Out:
# Dataframe's columns names:
# PassengerId
# Survived
# Pclass
# Name
# Sex
# Age
# SibSp
# Parch
# Ticket
# Fare
# Cabin
# Embarked
#
# The dimensionality of this df:
# 891 - numbers of rows
# 12 - numbers of columns

# %% [markdown]
# ##Task 3. Calculate how many men and women are in the dataset (0.5 pt)

# %%
men=df[df["Sex"]=='male'].shape[0]
print(f"The number of men: {men}")
women=df[df["Sex"]=='female'].shape[0]
print(f"The number of women: {women}")
if women+men==dem[0]:
  print("The number of columns equals number of men+women. That is all right")
# Out:
# The number of men: 577
# The number of women: 314
# The number of columns equals number of men+women. That is all right

# %% [markdown]
# #Task 4. Calculate survival rate for men and women (0.5 pt)

# %%
survived_male = df[(df['Survived'] == 1) & (df['Sex'] == 'male')]
survived_female = df[(df['Survived'] == 1) & (df['Sex'] == 'female')]

w_p=survived_female.shape[0]*100/dem[0]
print(f"Percentage of female survivors: {w_p}")
print(f"Percentage of male survivors: {100-w_p}")
# Out:
# Percentage of female survivors: 26.150392817059483
# Percentage of male survivors: 73.84960718294052

# %% [markdown]
# #Task 5. Group the data by Pclass and and display statistics on Age and Fare (1 pt)

# %%
grouped_data = df.groupby('Pclass')[['Age', 'Fare']].describe()
print(grouped_data)
# Out:
#           Age                                                       Fare  \
#         count       mean        std   min   25%   50%   75%   max  count
# Pclass
# 1       186.0  38.233441  14.802856  0.92  27.0  37.0  49.0  80.0  216.0
# 2       173.0  29.877630  14.001077  0.67  23.0  29.0  36.0  70.0  184.0
# 3       355.0  25.140620  12.495398  0.42  18.0  24.0  32.0  74.0  491.0
#
#
#              mean        std  min       25%      50%   75%       max
# Pclass
# 1       84.154687  78.380373  0.0  30.92395  60.2875  93.5  512.3292
# 2       20.662183  13.417399  0.0  13.00000  14.2500  26.0   73.5000
# 3       13.675550  11.778142  0.0   7.75000   8.0500  15.5   69.5500

# %% [markdown]
# #Task 6. What is the most popular family name in the dataset (1 pt)

# %%
most_common_family = df['Name'].str.split(',').str[0].value_counts().idxmax()
print(most_common_family)
# Out:
# Andersson

# %% [markdown]
# ##Task 7. What is the mean and std for all columns for survived male passengers (1 pt)

# %%
men_df=df[(df["Sex"]=='male') & (df['Survived'] == 1)]
"""
Delete this column because it's just an
identifier that doesn't affect the probability of survival
"""
del men_df['PassengerId']
print("Mean values:")
print(men_df.mean())
print("STD values:")
print(men_df.std())
# Out:
# Mean values:
# Survived     1.000000
# Pclass       2.018349
# Age         27.276022
# SibSp        0.385321
# Parch        0.357798
# Fare        40.821484
# dtype: float64
# STD values:
# Survived     0.000000
# Pclass       0.922774
# Age         16.504803
# SibSp        0.636952
# Parch        0.645826
# Fare        71.355967
# dtype: float64
# <ipython-input-9-8e1882334d29>:8: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(men_df.mean())
# <ipython-input-9-8e1882334d29>:10: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
# ...

# %% [markdown]
# #Task 8. Display rows from 40th to 60th (in numeration from zero) (1 pt)

# %%
df_40_60=df.iloc[40:61].reset_index(drop=True)
print(df_40_60)
# Out:
#     PassengerId  Survived  Pclass  \
# 0            40         1       3
# 1            41         0       3
# 2            42         0       2
# 3            43         0       3
# 4            44         1       2
# 5            45         1       3
# 6            46         0       3
# 7            47         0       3
# 8            48         1       3
# 9            49         0       3
# 10           50         0       3
# 11           51         0       3
# 12           52         0       3
# 13           53         1       1
# 14           54         1       2
# 15           55         0       1
# 16           56         1       1
# 17           57         1       2
# 18           58         0       3
# 19           59         1       2
# 20           60         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                         Nicola-Yarred, Miss. Jamila  female  14.0      1
# ...

# %% [markdown]
# ##Task 9. Sort the table by Fare in descending order (1 pt)

# %%
sorted_df = df.sort_values(by='Fare', ascending=False)
print(sorted_df)
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 737          738         1       1              Lesurer, Mr. Gustave J
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 88            89         1       1          Fortune, Miss. Mabel Helen
# 27            28         0       1      Fortune, Mr. Charles Alexander
# ..           ...       ...     ...                                 ...
# 633          634         0       1       Parr, Mr. William Henry Marsh
# 413          414         0       2      Cunningham, Mr. Alfred Fleming
# 822          823         0       1     Reuchlin, Jonkheer. John George
# 732          733         0       2                Knight, Mr. Robert J
# 674          675         0       2          Watson, Mr. Ennis Hastings
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %% [markdown]
# ##Task 10 Implement simple model to predict whether the person have survived according to knowledge you got from data analysis. Then calculate accuracy of your predictions on the dataset. Try to maximize accuracy (a student with maximum accuracy will recieve additional points). For example, the simplest model may look like (df["predict_survived"] = df["Sex"] == "male") (3 pt)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

# Применяю Label Encoding к столбцу Embarkedf
df['Embarked'] = label_encoder.fit_transform(df['Embarked'])

df['Cabin'] = label_encoder.fit_transform(df['Cabin'])



df['Sex'] = df['Sex'].replace({'male': 1, 'female': 0})
# Удаляем строки с пропущенными значениями
df.dropna(subset=['Pclass', 'Sex', 'Age','SibSp','Parch','Fare','Cabin','Embarked'], inplace=True)
x = np.array(df[['Pclass', 'Sex', 'Age','SibSp','Parch','Fare','Cabin','Embarked']])


y = np.array(df[["Survived"]])
# Преобраз в одномерный массив
y = y.ravel()

# Разделяем данные на обучающую и тестовые выборки
# Обучение модели будет происходить на 65% данных, а тесты на 35%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.35, random_state=42)


# Создание и обучение модели логистической регрессии

# Для сходимости
model = LogisticRegression(max_iter=10000)
model.fit(xtrain, ytrain)

# Предсказание на тестовом наборе
y_pred = model.predict(xtest)

# Оценка производительности модели
accuracy = accuracy_score(ytest, y_pred)
report = classification_report(ytest, y_pred)

print("Accuracy:", accuracy)
print("Classification Report:\n", report)
# Out:
# Accuracy: 0.756
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.77      0.83      0.80       145
#            1       0.73      0.66      0.69       105
#
#     accuracy                           0.76       250
#    macro avg       0.75      0.74      0.75       250
# weighted avg       0.75      0.76      0.75       250
